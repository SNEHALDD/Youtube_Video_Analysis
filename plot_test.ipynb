# %%
from data_loader import *
import plotly.express as px
import pandas as pd
from statsmodels import *

template = 'seaborn'

# %%
# get custom_url from binned_data2
channel_data2 = channel_data2.merge(binned_data2[['channel_id_x', 'custom_url']], on='channel_id_x', how='left')

channel_data2
# Out:
#                     channel_id_x  channel_view_count  subscriber_count  \
# 0       UC-8Q-hLdECwQmaWNwXitYDw        2.295032e+10        22000000.0
# 1       UC-8Q-hLdECwQmaWNwXitYDw        2.295032e+10        22000000.0
# 2       UC-8Q-hLdECwQmaWNwXitYDw        2.295032e+10        22000000.0
# 3       UC-8Q-hLdECwQmaWNwXitYDw        2.295032e+10        22000000.0
# 4       UC-8Q-hLdECwQmaWNwXitYDw        2.295032e+10        22000000.0
# ...                          ...                 ...               ...
# 509808  UCzOwecflGQFfHvMp-vMJCgQ        4.622420e+05            2620.0
# 509809  UCzOwecflGQFfHvMp-vMJCgQ        4.622420e+05            2620.0
# 509810  UCzOwecflGQFfHvMp-vMJCgQ        4.622420e+05            2620.0
# 509811  UCzOwecflGQFfHvMp-vMJCgQ        4.622420e+05            2620.0
# 509812  UCzOwecflGQFfHvMp-vMJCgQ        4.622420e+05            2620.0
#
#         channel_video_count    like_count  comment_count    view_count  \
# 0                     262.0  265012.21875    17332.46875  1.165580e+07
# 1                     262.0  265012.21875    17332.46875  1.165580e+07
# 2                     262.0  265012.21875    17332.46875  1.165580e+07
# 3                     262.0  265012.21875    17332.46875  1.165580e+07
# 4                     262.0  265012.21875    17332.46875  1.165580e+07
# ...                     ...           ...            ...           ...
# 509808                275.0      56.70000       34.84000  1.369200e+03
# 509809                275.0      56.70000       34.84000  1.369200e+03
# 509810                275.0      56.70000       34.84000  1.369200e+03
# 509811                275.0      56.70000       34.84000  1.369200e+03
# 509812                275.0      56.70000       34.84000  1.369200e+03
#
#         video_comment_count   video_likes   video_views  new_length  \
# 0               17332.46875  265012.21875  1.165580e+07   189.21875
# 1               17332.46875  265012.21875  1.165580e+07   189.21875
# 2               17332.46875  265012.21875  1.165580e+07   189.21875
# 3               17332.46875  265012.21875  1.165580e+07   189.21875
# 4               17332.46875  265012.21875  1.165580e+07   189.21875
# ...                     ...           ...           ...         ...
# 509808             34.84000      56.70000  1.369200e+03   557.44000
# 509809             34.84000      56.70000  1.369200e+03   557.44000
# 509810             34.84000      56.70000  1.369200e+03   557.44000
# 509811             34.84000      56.70000  1.369200e+03   557.44000
# 509812             34.84000      56.70000  1.369200e+03   557.44000
#
#                custom_url_x         custom_url_y
# 0            @katyperryvevo       @katyperryvevo
# 1            @katyperryvevo       @katyperryvevo
# 2            @katyperryvevo       @katyperryvevo
# 3            @katyperryvevo       @katyperryvevo
# 4            @katyperryvevo       @katyperryvevo
# ...                     ...                  ...
# 509808  @oldtimewhimcooking  @oldtimewhimcooking
# 509809  @oldtimewhimcooking  @oldtimewhimcooking
# 509810  @oldtimewhimcooking  @oldtimewhimcooking
# 509811  @oldtimewhimcooking  @oldtimewhimcooking
# 509812  @oldtimewhimcooking  @oldtimewhimcooking
#
# [509813 rows x 13 columns]
