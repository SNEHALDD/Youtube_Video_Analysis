# %%
#import dependencies
import os
import psycopg2
import subprocess
from config import host,database,user,password
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf
from sklearn.linear_model import LogisticRegression

# %%
conn=psycopg2.connect(
    host=host,
    database=database,
    user=user,
    password=password)

cur=conn.cursor()
cur.execute("SELECT * FROM joined_data;")
print(cur.fetchall())
conn.commit()

#close out
cur.close()
conn.close()
# Out:
# [('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'lmH5uqwaFq8', datetime.datetime(2022, 11, 1, 7, 0, 15), '2:59', 19653, 0, 3425275), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, '0SY0Yn0yF9o', datetime.datetime(2022, 10, 29, 7, 0), '29:52:00', 15076, 0, 2882582), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'sNyF7BvVfxs', datetime.datetime(2022, 10, 25, 7, 0, 16), '2:49', 47763, 0, 8673081), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'K4kqqCzF-BA', datetime.datetime(2022, 10, 22, 7, 0, 12), '1:01:21', 57936, 0, 11744611), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'gfZmvllWVwY', datetime.datetime(2022, 10, 18, 7, 0, 19), '2:39', 46041, 0, 8775011), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'Ay3m-zZ4KLs', datetime.datetime(2022, 10, 15, 7, 0, 8), '29:00:00', 82258, 0, 14759237), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'mbPNkDEN3Ps', datetime.datetime(2022, 10, 11, 7, 0, 16), '3:29', 84510, 0, 18552188), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'kSx1tS52ov4', datetime.datetime(2022, 10, 7, 23, 0, 34), '56:41:00', 70038, 0, 14267136), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'o3eMkWX8E7U', datetime.datetime(2022, 10, 4, 7, 0, 31), '2:49', 56693, 0, 11852093), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'o1YenjwOp-A', datetime.datetime(2022, 10, 1, 7, 0, 17), '34:54:00', 70499, 0, 12609085), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'hqFfJBOrvHw', datetime.datetime(2022, 9, 27, 7, 0, 15), '2:42', 33185, 0, 8768272), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'QYTYKUMOuwo', datetime.datetime(2022, 9, 24, 7, 0, 8), '1:10', 75600, 0, 14603713), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'biXYtxZnChQ', datetime.datetime(2022, 9, 20, 7, 53, 6), '2:58', 44981, 0, 11860119), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'tkTYVy5sdIg', datetime.datetime(2022, 9, 17, 7, 18, 34), '56:52:00', 77693, 0, 14328606), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, '-4nWoQwSHGE', datetime.datetime(2022, 9, 13, 7, 4, 39), '3:14', 56364, 0, 11783626), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'zhoVe42Pxb0', datetime.datetime(2022, 9, 10, 7, 0, 31), '35:46:00', 88588, 0, 19193110), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'lkBlyggtYhA', datetime.datetime(2022, 9, 6, 7, 0, 11), '2:56', 63394, 0, 17121975), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, '3rKIRUm5oV4', datetime.datetime(2022, 9, 3, 7, 0, 1), '54:50:00', 71791, 0, 16178857), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, '3QFTTxD7SuY', datetime.datetime(2022, 8, 30, 9, 15, 48), '3:05', 89279, 0, 17317788), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'DqhH2OUOl1M', datetime.datetime(2022, 8, 27, 7, 0, 3), '28:18:00', 84488, 0, 22193229), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'SSe98txCv00', datetime.datetime(2022, 8, 23, 7, 0, 8), '2:54', 230384, 0, 78686530), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'uHJN15kVTLY', datetime.datetime(2022, 8, 20, 7, 0, 16), '59:27:00', 84273, 0, 16730793), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'zHvKlszHzCg', datetime.datetime(2022, 8, 16, 7, 0, 15), '2:52', 86029, 0, 23195106), ('UCbCmjCuTUZos6Inko4u57UQ', '@cocomelon', 'Music', 142468175305, 146000000, 811, 'dxjciWnjd0M', datet ...
