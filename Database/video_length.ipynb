# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SNEHALDD/Youtube_Video_Analysis/Kevin2/Database/ready_for_sql/video_data_fixed_length.csv")
df
# Out:
#                     channel_id     video_id  \
# 0     UCbCmjCuTUZos6Inko4u57UQ  lmH5uqwaFq8
# 1     UCbCmjCuTUZos6Inko4u57UQ  0SY0Yn0yF9o
# 2     UCbCmjCuTUZos6Inko4u57UQ  sNyF7BvVfxs
# 3     UCbCmjCuTUZos6Inko4u57UQ  K4kqqCzF-BA
# 4     UCbCmjCuTUZos6Inko4u57UQ  gfZmvllWVwY
# ...                        ...          ...
# 8599  UCC7jlYxfWti7WAW8r7ef1RQ  xRi8SGcRDOY
# 8600  UCC7jlYxfWti7WAW8r7ef1RQ  C-34pIsWZPk
# 8601  UCC7jlYxfWti7WAW8r7ef1RQ  L2GdB1gB1ZM
# 8602  UCC7jlYxfWti7WAW8r7ef1RQ  89IewFGQQ6E
# 8603  UCC7jlYxfWti7WAW8r7ef1RQ  QS32cM-BQ6M
#
#                                       video_title_clean  \
# 0     Airplane Song CoComelon Nursery Rhymes Kids Songs
# 1     Wheels On The Bus More Nursery Rhymes Kids Son...
# 2     Bingos Bath Song CoComelon Nursery Rhymes Kids...
# 3     Play Outside at the Beach Song More Nursery Rh...
# 4     Halloween Song Dance Dance Party CoComelon Nur...
# ...                                                 ...
# ...

# %%
df.dtypes
# Out:
# channel_id              object
# video_id                object
# video_title_clean       object
# published               object
# video_length            object
# video_comment_count      int64
# video_likes              int64
# video_views              int64
# new_length             float64
# dtype: object

# %%
#drop all columns except video id and new length
df=df.drop(columns=['channel_id','video_title_clean','published','video_length','video_comment_count','video_likes','video_views'])
df
# Out:
#          video_id  new_length
# 0     lmH5uqwaFq8       179.0
# 1     0SY0Yn0yF9o      1792.0
# 2     sNyF7BvVfxs       169.0
# 3     K4kqqCzF-BA      3681.0
# 4     gfZmvllWVwY       159.0
# ...           ...         ...
# 8599  xRi8SGcRDOY         9.0
# 8600  C-34pIsWZPk       289.0
# 8601  L2GdB1gB1ZM        16.0
# 8602  89IewFGQQ6E        16.0
# 8603  QS32cM-BQ6M        11.0
#
# [8604 rows x 2 columns]

# %%
#save csv and join on sql
df.to_csv("ready_for_sql/video_length.csv",index=False)

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/SNEHALDD/Youtube_Video_Analysis/Kevin2/Database/ready_for_sql/video_data_fixed_length.csv")
df2
# Out:
#                     channel_id     video_id  \
# 0     UCbCmjCuTUZos6Inko4u57UQ  lmH5uqwaFq8
# 1     UCbCmjCuTUZos6Inko4u57UQ  0SY0Yn0yF9o
# 2     UCbCmjCuTUZos6Inko4u57UQ  sNyF7BvVfxs
# 3     UCbCmjCuTUZos6Inko4u57UQ  K4kqqCzF-BA
# 4     UCbCmjCuTUZos6Inko4u57UQ  gfZmvllWVwY
# ...                        ...          ...
# 8599  UCC7jlYxfWti7WAW8r7ef1RQ  xRi8SGcRDOY
# 8600  UCC7jlYxfWti7WAW8r7ef1RQ  C-34pIsWZPk
# 8601  UCC7jlYxfWti7WAW8r7ef1RQ  L2GdB1gB1ZM
# 8602  UCC7jlYxfWti7WAW8r7ef1RQ  89IewFGQQ6E
# 8603  UCC7jlYxfWti7WAW8r7ef1RQ  QS32cM-BQ6M
#
#                                       video_title_clean  \
# 0     Airplane Song CoComelon Nursery Rhymes Kids Songs
# 1     Wheels On The Bus More Nursery Rhymes Kids Son...
# 2     Bingos Bath Song CoComelon Nursery Rhymes Kids...
# 3     Play Outside at the Beach Song More Nursery Rh...
# 4     Halloween Song Dance Dance Party CoComelon Nur...
# ...                                                 ...
# ...

# %%
#drop all columns except video id and new length
df2=df2.drop(columns=['channel_id','video_title_clean','published','video_comment_count','video_likes','video_views'])
df2
# Out:
#          video_id video_length  new_length
# 0     lmH5uqwaFq8         2:59       179.0
# 1     0SY0Yn0yF9o     29:52:00      1792.0
# 2     sNyF7BvVfxs         2:49       169.0
# 3     K4kqqCzF-BA      1:01:21      3681.0
# 4     gfZmvllWVwY         2:39       159.0
# ...           ...          ...         ...
# 8599  xRi8SGcRDOY            9         9.0
# 8600  C-34pIsWZPk         4:49       289.0
# 8601  L2GdB1gB1ZM           16        16.0
# 8602  89IewFGQQ6E           16        16.0
# 8603  QS32cM-BQ6M           11        11.0
#
# [8604 rows x 3 columns]

# %%
df2.to_csv("ready_for_sql/video_length_with_sec.csv", index=False)

# %%
file=pd.read_csv("ready_for_sql/video_length_with_sec.csv")
file.dtypes
# Out:
# video_id         object
# video_length     object
# new_length      float64
# dtype: object
